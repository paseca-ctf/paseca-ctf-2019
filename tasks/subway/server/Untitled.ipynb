# %%
import pandas as pd
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")
print(nx.__version__)
# %matplotlib inline
# Out:
# 2.3

# %%
street_names = set(pd.read_csv('street-names.csv')['StreetName'])
street_names
# Out:
# {'CARSON',
#  'GORHAM',
#  'INFANTRY',
#  'MARLIN',
#  'DELANO',
#  'ROACH',
#  'ARKANSAS',
#  'ORSI',
#  'SAN JUAN',
#  '10TH TI',
#  'POWERS',
#  'GERMANIA',
#  'HAWTHORNE',
#  'WALLACE',
#  'HALYBURTON',
#  'LANDERS',
#  'FITCH',
#  'DELTA',
#  'BOWDOIN',
#  'CHURCH ACCESS',
#  'BLANCHE',
#  'FORT MASON 16',
#  'GREELY',
#  'COLERIDGE',
#  'MARGRAVE',
#  'MOSS',
#  'NORTH HUGHES',
#  'RIPLEY',
#  'EDINBURGH',
#  'LEE',
#  'PINE',
#  'ALVORD',
#  'PATTEN',
#  'SHEPHARD',
#  'STANFORD',
#  'SFGH ACCESS',
#  'BATTERY WAGNER',
#  'ACEVEDO',
#  'BELLES',
#  'JUDSON',
#  'GENEVA',
#  'MINNA',
#  'CHATTANOOGA',
#  'EMMA',
#  'LAPIDGE',
#  'CARPENTER',
#  'OLYMPIA',
#  'LONE MOUNTAIN',
#  'DAY',
#  'PRECITA',
#  'STERLING',
#  'ZIRCON',
#  'LOCKWOOD',
#  'FLINT',
#  'ROANOKE',
#  'CRAIG',
#  'HOOKER',
#  'LUSK',
#  'WASHINGTON',
#  'LUCKY',
#  'KENWOOD',
#  'ROSIE LEE',
#  'BROOKS',
#  'VENUS',
#  'MARNE',
#  'J',
#  'FILLMORE',
#  'HARRIS',
#  '03RD TI',
#  'GOLDBERG',
#  'DAWNVIEW',
#  'SEVERN',
#  'CLAUDE',
#  'DUNSHEE',
#  'BERRY EXTENSION',
#  'MONTE VISTA',
#  'NORTHRIDGE',
#  'CARGO',
#  'MANCHESTER',
#  'DEMING',
#  'HYDE',
#  'STILLMAN',
#  'ISADORA DUNCAN',
#  'GRAHAM',
#  'GOLDEN GATE',
#  'LONDON',
#  'HERMANN',
#  'LAGUNITAS',
#  'ELDRIDGE',
#  'JOHN F SHELLEY',
#  'TOMASO',
#  'POND',
#  'ANDOVER',
#  'BAYWOOD',
#  'BLACKSTONE',
#  'CALGARY',
#  'FIRST',
#  'CASTILLO',
#  'DRUMM',
#  'STORRIE',
#  'CHAPMAN',
#  'MCLAREN LODGE ACCESS',
#  'GARCES',
#  'OZBOURN',
#  'VIRGIL',
#  'BLAIRWOOD',
#  'LETTERMAN',
#  'TRINITY',
#  'DANIEL BURNHAM',
#  'MANSEAU',
#  'PORTER',
#  'HOLYOKE',
#  'BELMONT',
#  'BURR',
#  'EAGLE',
#  'WAWONA',
#  '39TH',
#  'BEULAH',
#  'HARRINGTON',
#  'BATTERY CROSBY',
#  'CRESPI',
#  'RODGERS',
#  'JOHN MUIR',
#  '07TH',
#  'EL POLIN',
#  'PACIFIC',
#  'GABILAN',
#  'HOLLIS',
#  'HOMEWOOD',
#  'WENTWORTH',
#  'WINFIELD',
#  'SHOUP',
#  'BOUTWELL',
#  'FRANCIS',
#  'PENNY',
#  'ISOLA',
#  'UNNAMED 152',
#  'BANKS',
#  'CUTLER',
#  'ATALAYA',
#  'ESSEX',
#  'CLARKE',
#  'COMERFORD',
#  'ALBION',
#  'ARBALLO',
#  'MILAN',
#  'ADELE',
#  'LIVINGSTON',
#  'TORNEY',
#  'HARKNESS',
#  'GILLETTE',
#  '45TH',
#  'ACME',
#  'UNNAMED 148',
#  'INCINERATOR',
#  'GOLETA',
#  'GLENDALE',
#  'DEL VALE',
#  'UNNAMED 026',
#  'BERTHA',
#  'DALEWOOD',
#  'THERESA',
#  'FREDERICK',
#  'LYON',
#  'BANCROFT',
#  'ISSLEIB',
#  'SWEENY',
#  'MARENGO',
#  'MERLIN',
#  'FARVIEW',
#  'HIMMELMANN',
#  'CORNWALL',
#  'COWELL',
#  'SUNSET',
#  'SAN FRANCISCO GOLF CLUB',
#  'SIXTH',
#  'UNNAMED 144',
#  'HAVENS',
#  'PIERCE',
#  'I-80 WESTBOUND',
#  'LUCY',
#  'MARIST',
#  'WHITNEY',
#  'JEROME',
#  'HUNTERS POINT',
#  'LULU',
#  'KNOLLVIEW',
#  'FREELON',
#  'DECATUR',
#  'HULBERT',
#  'LESTER',
#  'CONTINUUM',
#  'ALVISO',
#  'DORMAN',
#  'BERGEN',
#  'TOMPKINS',
#  'UNNAMED 129',
#  'SUNGLOW',
#  'MOJAVE',
#  'WEST PORTAL',
#  'COOK',
#  'MCKINLEY',
#  'OMAR',
#  'KATE',
#  'WISCONSIN',
#  'GARDENSIDE',
#  'STEUBEN',
#  'BROOKDALE',
#  'FINLEY',
#  'FOREST HILL',
#  'EUREKA',
#  'NICHOLS',
#  'TAMPA',
#  'DELLBROOK',
#  'MAHAN',
#  'LICK',
#  'CARDENAS',
#  'GALVEZ',
#  'SADDLEBACK',
#  'RED ROCK',
#  'CAINE',
#  'ANZA',
#  'BRICE',
#  'BRIDGEVIEW',
#  'CAMBRIDGE',
#  'LARCH',
#  'BERNICE RODGERS',
#  'OAK ACCESS',
#  'DORCAS',
#  'PALMETTO',
#  'LUNDYS',
#  'OLMSTEAD',
#  'NEWHALL',
#  'SCHOOL',
#  'GALLAGHER',
#  'ASHTON',
#  'KENNEDY',
#  'CASITAS',
#  'UPPER',
#  'WHITTIER',
#  'ELIM',
#  'LAMSON',
#  'CARTER',
#  'OLIVER',
#  'MONUMENT',
#  'ROSELYN',
#  'DESMOND',
#  'BANBURY',
#  'CONCOURSE',
#  'BUCHANAN',
#  'SOUTH PARK',
#  'TRAINOR',
#  'CLEARFIELD',
#  'TELEGRAPH HILL',
#  'ARDENWOOD',
#  'GATEVIEW',
#  'GARFIELD',
#  'KENT',
#  'WEST BROADWAY',
#  'KOHLER',
#  'COCHRANE',
#  'MINT',
#  'RIO VERDE',
#  'RUTLEDGE',
#  'FREDSON',
#  'SKYVIEW',
#  'AUGUST',
#  'EMIL',
#  'HILIRITAS',
#  'THORNTON',
#  'DOVE',
#  'MATTHEW',
#  'GOETHE',
#  'GREENWICH',
#  'BELLE',
#  'NIMITZ',
#  'ELM',
#  '14TH',
#  'BLAIR',
#  'NIDO',
#  'ROSSI',
#  'ABBEY',
#  'HARRIET',
#  'CUSHMAN',
#  'DOCK',
#  'ARLETA',
#  'PENINSULA',
#  'PINO',
#  'ASPEN',
#  'LITTLEFIELD',
#  'OCEANVIEW',
#  'QUINCY',
#  'SHORT',
#  'OAK',
#  'RACCOON',
#  'BYXBEE',
#  'BACHE',
#  'MENDELL',
#  'SUNBEAM',
#  'OFARRELL',
#  'SONOMA',
#  'BAYSIDE VILLAGE',
#  'UNNAMED 106',
#  'VAN DYKE',
#  'MONTCALM',
#  'WINTER',
#  'MILEY',
#  'CHURCH',
#  'GRANT',
#  'SENECA',
#  'AMITY',
#  'TACOMA',
#  'MARSHALL',
#  'BLYTHDALE',
#  'HALLAM',
#  'HWY 101 S OFF',
#  'POPLAR',
#  'BARTOL',
#  'OLD CHINATOWN',
#  'EL DORADO',
#  'HAVENSIDE',
#  'BEAVER',
#  'STANTON',
#  'EUGENIA',
#  'RADIO',
#  'BERRY',
#  'GOLD',
#  'MADISON',
#  'MIGUEL',
#  'WARD',
#  'STANFORD HEIGHTS',
#  'CHARLES',
#  'THE EMBARCADERO',
#  'GLADIOLUS',
#  'REDDY',
#  'ROCKRIDGE',
#  'VISTA',
#  'SEAWELL',
#  'POMONA',
#  'UTAH',
#  'GARDEN',
#  'ENTERPRISE',
#  '06TH',
#  'RITCH',
#  'CHINA BASIN',
#  'ARGONAUT',
#  'DEEMS',
#  'RICHARDS',
#  'HATTIE',
#  'HEALY',
#  'CLOVER',
#  'ENGLISH',
#  'FAXON',
#  'JUNIPERO SERRA BLVD OFF',
#  'BRENTWOOD',
#  'LAPHAM',
#  'MARYLAND',
#  'OTSEGO',
#  'SCIENCE',
#  'CLOUD',
#  'TURK',
#  'ARMSTRONG',
#  'HOLLOWAY',
#  'CASTENADA',
#  'CLARENDON',
#  'DOUGLASS',
#  'SAN JOSE',
#  'UNNAMED 139',
#  'VERMONT',
#  'FARALLONES',
#  'CATHERINE',
#  'BELLAIR',
#  'EUCLID',
#  'FORT MASON 17',
#  'ITALY',
#  'THORP',
#  'STARR KING',
#  'CHABOT',
#  'MARTIN',
#  '09TH',
#  'NAVAJO',
#  'CORONA',
#  'CRESTLAKE',
#  'SAGAMORE',
#  'LOCKSLEY',
#  'GLOBE',
#  '22ND',
#  '34TH',
#  'BUCARELI',
#  'JOHNSTONE',
#  'TIFFANY',
#  'COLIN',
#  'WOODHAVEN',
#  'UNNAMED 041',
#  'VEGA',
#  'FRANCONIA',
#  'VON SCHMIDT',
#  'CADELL',
#  'BAY',
#  'ALDER',
#  'TRENTON',
#  'RUSSIA',
#  'STANYAN',
#  'MARTIN LUTHER KING JR',
#  'FOREST',
#  'LOCUST',
#  'DUBOCE',
#  'LAWRENCE',
#  'LOMA VISTA',
#  'PENA',
#  'LILLIAN',
#  'CARR',
#  'ULLOA',
#  'HUDSON',
#  'EDWARD',
#  'CHINOOK',
#  'GORDON',
#  'JURI',
#  'TERRY A FRANCOIS',
#  'COLIN P KELLY JR',
#  'VALLEY',
#  'AGNON',
#  'BEAUMONT',
#  'STEVELOE',
#  'DE SOTO',
#  'CASTLE MANOR',
#  'FOREST VIEW',
#  'POTRERO',
#  'BANNAN',
#  'HWY 101 N ON',
#  'NEVADA',
#  'ALMA',
#  'SANCHEZ',
#  'NEWTON',
#  'CASHMERE',
#  'TULARE',
#  'PLAZA',
#  'VARA',
#  'NAHUA',
#  'LETTERMAN HOSPITAL ACCESS',
#  'CODMAN',
#  'JESSIE',
#  'GLENVIEW',
#  'PUEBLO',
#  'COOPER',
#  'DELMAR',
#  'PINTO',
#  'LORAINE',
#  'ROYAL',
#  'SERGEANT JOHN V YOUNG',
#  '13TH',
#  'ALEMANY BLVD OFF',
#  'BOB KAUFMAN',
#  'DRUMMOND',
#  'SEWARD',
#  'WOODLAND',
#  'LUNADO',
#  'MASSASOIT',
#  'ASHBURY',
#  'WEST HALLECK',
#  'SCENIC',
#  'ALTA VISTA',
#  'GROVE',
#  'ADOLPH SUTRO',
#  'I-80 W ON',
#  'UNNAMED 112',
#  'UNNAMED 115',
#  'SOUTH HUGHES',
#  'JOHN',
#  'BERKSHIRE',
#  'RAYCLIFF',
#  'EASTMAN',
#  'SPROULE',
#  'BARTLETT',
#  'THOMAS',
#  'UNNAMED 107',
#  'DAGGETT',
#  'ACACIA',
#  'ROSSMOOR',
#  'UNITED NATIONS',
#  'HARDING',
#  'COMPTON',
#  'COSTA',
#  'CHESTNUT',
#  'DARRELL',
#  'LAGUNA',
#  'BENTON',
#  'CEDAR',
#  'TONQUIN',
#  'AVENUE M',
#  'FENTON',
#  'GENEBERN',
#  'KEMPTON',
#  'BEMIS',
#  'BOCANA',
#  'ORIOLE',
#  'SHIPLEY',
#  'UPPER SERVICE',
#  'INGERSON',
#  'LATHROP',
#  'SUTTER',
#  'JEWETT',
#  'MERCURY',
#  'FRONT',
#  'BREEN',
#  'OLNEY',
#  'STONEYFORD',
#  'BOWLEY',
#  'BROMLEY',
#  'UNNAMED 090',
#  'DAKOTA',
#  'UNNAMED 108',
#  'MISSION',
#  'SPARROW',
#  'OPAL',
#  'FRESNO',
#  'GRIFFITH',
#  'BRAZIL',
#  'MCCOPPIN',
#  'ESMERALDA',
#  'PLYMOUTH',
#  'I-80 E ON',
#  'NEWCOMB',
#  'CASE',
#  'BAY VIEW',
#  'NAPLES',
#  'AVENUE F',
#  'LEDYARD',
#  'AZTEC',
#  'MOUNTAIN SPRING',
#  'DARIEN',
#  'CRAGS',
#  'EL PLAZUELA',
#  'AVERY',
#  '12TH',
#  'VAN NESS',
#  'WANDA',
#  'INDUSTRIAL ST ON',
#  'WATER',
#  'CLINTON',
#  'METSON',
#  'AMADOR',
#  'PAULDING',
#  'SANTA CRUZ',
#  'SALA',
#  'SEA VIEW',
#  '26TH',
#  'SAN LUIS',
#  'NADELL',
#  'THOMAS MORE',
#  'BIGLER',
#  'FELL ACCESS',
#  'PARADISE',
#  'LOMBARD',
#  '18TH',
#  'BOALT',
#  'UNNAMED 012',
#  'TEMPLE',
#  'PROGRESS',
#  'HERON',
#  'VIDAL',
#  'NANCY PELOSI',
#  'WILLIE B KENNEDY',
#  'THRIFT',
#  'NAGLEE',
#  'WIESE',
#  'STRATFORD',
#  'DUNNES',
#  'ANZAVISTA',
#  'GOLDING',
#  'LAUSSAT',
#  'SICKLES',
#  'BLUXOME',
#  'MARION',
#  'YORBA',
#  'BURLWOOD',
#  'ROCK',
#  'PIXLEY',
#  'EDGARDO',
#  'MICHIGAN',
#  'ANKENY',
#  'KAMILLE',
#  'FREEMAN',
#  'MABINI',
#  'FEDERAL',
#  'CHULA',
#  'SELMA',
#  'CHILD',
#  'RICE',
#  'HWY 1 SOUTHBOUND',
#  'WINSTON',
#  'CUESTA',
#  'CARROLL',
#  'ONEIDA',
#  'JONES',
#  'DELGADO',
#  'PORTOLA',
#  'DORMITORY',
#  'GRIJALVA',
#  'VIENNA',
#  'FELL',
#  'BERNAL HEIGHTS',
#  'ORANGE',
#  'VERDI',
#  'HORACE',
#  'SHRADER',
#  'UNNAMED 128',
#  'SERVICE',
#  'CLEMENTINA',
#  'BAY SHORE',
#  'BLAKE',
#  'LUCERNE',
#  'UNNAMED 071',
#  'PALO ALTO',
#  'BIRCHWOOD',
#  'MUIR',
#  'BORICA',
#  '46TH',
#  'CECILIA',
#  'VESTA',
#  'NAUTILUS',
#  'MORAGA',
#  'UNNAMED 044',
#  'RINGOLD',
#  'THOR',
#  'MILLER',
#  'PALOMA',
#  'ROSCOE',
#  'ELLINGTON',
#  'WISSER',
#  'BAY SHORE BLVD OFF',
#  'HWY 101 S ON',
#  'BARNARD',
#  'EASEMENT',
#  'HOBART',
#  'WALNUT',
#  'LIBERTY',
#  'FORT MASON 21',
#  'RUDDEN',
#  'WILSON',
#  'UNNAMED 187',
#  'MUSIC CONCOURSE',
#  'BELL',
#  'AHERN',
#  'APPLETON',
#  'CHANCERY',
#  'ORDWAY',
#  'KEPPLER',
#  'LASKIE',
#  'HAWKINS',
#  'HOFFMAN',
#  'SOUTHWOOD',
#  'SUNRISE',
#  'ANGLO',
#  'JERSEY',
#  'ATTRIDGE',
#  'GIBBON',
#  'CRANLEIGH',
#  'ALICE B TOKLAS',
#  'EDGAR',
#  'SUNNYSIDE',
#  'KOBBE',
#  'ALBATROSS',
#  'CORALINO',
#  'MYRTLE',
#  'CUBA',
#  'GELLERT',
#  'UNNAMED 083',
#  'QUICKSTEP',
#  'WALBRIDGE',
#  'JUNIPERO SERRA',
#  'KING',
#  'KIRKHAM',
#  'RIDGE',
#  'PARK PRESIDIO BYPASS',
#  'DUDLEY',
#  'SANCHES',
#  'EXCELSIOR',
#  'COMMER',
#  'ARBOR',
#  'STONERIDGE',
#  'WILDE',
#  'JARBOE',
#  'ELK',
#  'BATTERY EAST',
#  'JACKSON',
#  'CORDELIA',
#  'MILL',
#  'PARK HILL',
#  'PUBLIC',
#  'BLANDY',
#  'NEWMAN',
#  'DUNCOMBE',
#  'UNNAMED 032',
#  'RAMSEL',
#  'HOOPER',
#  'IMPERIAL',
#  'HILLCREST',
#  'HUNT',
#  'OAK GROVE',
#  'RIVERTON',
#  'UNNAMED 010',
#  'RANKIN',
#  'STEINER',
#  'EL MIRASOL',
#  'ADMIRAL',
#  'CASTRO',
#  'IGNACIO',
#  'BROTHERHOOD',
#  'BACON',
#  'CORTLAND',
#  'CURTIS',
#  'JEFFERSON',
#  'LA BICA',
#  'BLISS',
#  'BARCELONA',
#  'SIERRA',
#  'LUDLOW',
#  'WESTBROOK',
#  'SAN BRUNO',
#  'UNNAMED 088',
#  'FRIENDSHIP',
#  'WESTMOORLAND',
#  'THORNBURG',
#  'WOODWARD',
#  'CHATHAM',
#  'PAUL',
#  'SANTA PAULA',
#  'RIZAL',
#  'LOPEZ',
#  'SAINT LOUIS',
#  'ENCLINE',
#  'SYLVAN',
#  'BAY SHORE BLVD ON',
#  'PHELPS',
#  'BRYANT',
#  'CLAIRVIEW',
#  'AVOCET',
#  'BATTERY BLANEY',
#  'POLARIS',
#  'AVON',
#  'MARVEL',
#  'CENTRAL',
#  'MISSISSIPPI',
#  'VARNEY',
#  'WALL',
#  'DAWSON',
#  'FELLA',
#  'GRAND VIEW',
#  'TULIP',
#  'ROSEMONT',
#  'GREENOUGH',
#  'STAPLES',
#  'OLORAN',
#  'EVERSON',
#  'DARTMOUTH',
#  '02ND TI',
#  'DONAHUE',
#  'ARELIOUS WALKER',
#  'EXCHANGE',
#  'STONE',
#  'UNNAMED 075',
#  'QUARTZ',
#  'LAMARTINE',
#  'HARDIE',
#  'WEST POINT',
#  'ALOHA',
#  'BADGER',
#  'CHESLEY',
#  'NORTH VAN HORN',
#  'MCCORMICK',
#  'WHEAT',
#  'BOYLSTON',
#  'MADERA',
#  'TOPEKA',
#  'ANNAPOLIS',
#  'CAMBON',
#  'MADRID',
#  'VETERANS',
#  'MASSACHUSETTS',
#  'FLOURNOY',
#  'MEDAU',
#  'VAN KEUREN',
#  'CARD',
#  'UNNAMED 069',
#  'JACK LONDON',
#  'EDDY',
#  'FORT MASON 10',
#  'GGP ACCESS ROAD',
#  'UNNAMED 120',
#  'LA PLAYA',
#  'MEACHAM',
#  'DAVIS',
#  'ANNIE',
#  'CHASE',
#  'MORTON',
#  '30TH',
#  'SAMPSON',
#  'JASPER',
#  'WHITFIELD',
#  'CAMEO',
#  'UNNAMED 014',
#  'COSGROVE',
#  'ALLEN',
#  'LAKE MERCED',
#  'SHORE VIEW',
#  'RIDGEWOOD',
#  'JULIUS',
#  'JAVA',
#  'VARENNES',
#  'WINDSOR',
#  'CHRISTMAS TREE POINT',
#  'DANVERS',
#  'MARINE',
#  'NORFOLK',
#  'BROADWAY',
#  'PERRY',
#  'NEPTUNE',
#  'JUDAH',
#  'SHERMAN',
#  'NORTH POINT',
#  'SECURITY PACIFIC',
#  'TILLMAN',
#  'EMERSON',
#  'CASELLI',
#  'CALIFORNIA',
#  'LINDSAY',
#  'ARROYO',
#  'WHEELER',
#  'BADEN',
#  'CRESTLINE',
#  'FAITH',
#  'LAFAYETTE',
#  'GENERAL KENNEDY',
#  'MARK',
#  'MERCATO',
#  'HARLAN',
#  'VANDEWATER',
#  'BROWN',
#  'DEL SUR',
#  'UNNAMED 142',
#  'LURLINE',
#  'ZOE',
#  'ROMOLO',
#  'CUSTOM HOUSE',
#  'GRAYSTONE',
#  'MERCED',
#  'MIRAMAR',
#  'DELAWARE',
#  'JUAN BAUTISTA',
#  'HUBBELL',
#  'VIA BUFANO',
#  'MOSCOW',
#  'FALMOUTH',
#  'RHODE ISLAND',
#  'WALKER',
#  'ROCKLAND',
#  'STILLINGS',
#  'MANOR',
#  'OSCEOLA',
#  'HOWARD',
#  'VENTURA',
#  'TABER',
#  'LLOYD',
#  'SAINT FRANCIS',
#  'IDORA',
#  'MADDUX',
#  'FORT MASON 18',
#  'HEYMAN',
#  'STURGEON',
#  '42ND',
#  'HARLEM',
#  'DELANCEY',
#  'UNNAMED 188',
#  'DAVENPORT',
#  'BRANT',
#  'REDFIELD',
#  'R',
#  'NEWELL',
#  'GARCIA',
#  'CERES',
#  'SLOAT',
#  'UNNAMED 145',
#  '09TH TI',
#  'GILROY',
#  'ELMIRA',
#  'MIDWAY',
#  'MARVIEW',
#  'ALLSTON',
#  'MIRANDO',
#  'PALACE',
#  'GALINDO',
#  'SANTA ANA',
#  'FOERSTER',
#  'TOPAZ',
#  'CONRAD',
#  'I-280 S OFF',
#  'PLUM',
#  'RICHARD HENRY DANA',
#  '11TH TI',
#  'KENSINGTON',
#  'WALLER',
#  'NEBRASKA',
#  'PAGE',
#  'OSAGE',
#  'BELDEN',
#  'UNNAMED 024',
#  'PARKER',
#  'BURNS',
#  'FRENCH',
#  'GUERRERO',
#  'MISSION BAY',
#  'FORTUNA',
#  'SHELDON',
#  'MANZANITA',
#  'WILLS',
#  'JENNIFER',
#  'OCEAN',
#  'MAIDEN',
#  'LARKIN',
#  'PASADENA',
#  'SAN BRUNO AV OFF',
#  'DIAMOND',
#  'BEACON',
#  'GRACE',
#  'ADAIR',
#  'GOLF COURSE ACCESS',
#  'NEWBURG',
#  'STRIPED BASS',
#  'SAN FELIPE',
#  'PFEIFFER',
#  'ALTON',
#  'RHINE',
#  'RESERVOIR',
#  'OAK PARK',
#  'SAN ANSELMO',
#  'SKYLINE',
#  'OXFORD',
#  'FRIEDELL',
#  'DANTON',
#  'CRAUT',
#  'MCDOWELL',
#  'PARAMOUNT',
#  'SOUTH GATE',
#  'I-280 TO HWY 101',
#  'JOY',
#  'LYELL',
#  'ALABAMA',
#  'MAGNOLIA',
#  'EXPOSITION',
#  'MCLEA',
#  'TIOGA',
#  'BEALE',
#  'BONNIE BRAE',
#  'GAVIOTA',
#  'SHANNON',
#  'WHITECLIFF',
#  'MINNESOTA',
#  'HANCOCK',
#  'BERTITA',
#  'CRISP',
#  'ANSON',
#  'SPENCER',
#  'NORTHWOOD',
#  'VELASCO',
#  'QUARRY',
#  'EMERALD',
#  'GETZ',
#  'BELVEDERE',
#  'I-80 E OFF',
#  'WHIPPLE',
#  'JACK KEROUAC',
#  'NORTH VIEW',
#  'UNNAMED 192',
#  'BALMY',
#  'NORTH 15TH',
#  'LELAND',
#  'HAYS',
#  'HOLLAND',
#  'CHESTER',
#  'WAGNER',
#  'UNNAMED 101',
#  'ARGENT',
#  'RUSSIAN HILL',
#  'DUNCAN',
#  'MOUNT',
#  'LIGGETT',
#  'AGUA',
#  'ROOSEVELT',
#  'SUNNYDALE',
#  'CATALINA',
#  'UNIVERSITY',
#  'MACALLA',
#  'RICHARDSON',
#  'UNNAMED 113',
#  'OHLONE',
#  '12TH TI',
#  'BELGRAVE',
#  'NOBLES',
#  'NIBBI',
#  ...}

# %%
from random import randint, choice, sample
from itertools import count
from dsu import DSU

def gen_graph(n_stations: list):
    G = nx.Graph()
    names = sample(street_names, sum(n_stations))
    assert len(names) == len(set(names))
    lines_names = list([i.title() for i in names])
    node_names = [lines_names[sum(n_stations[:c]):sum(n_stations[:c]) + stations] for c, stations in zip(count(), n_stations)]
    lines = []
    for c, stations in zip(count(), n_stations):
        G.add_nodes_from(node_names[c], color = c / (len(n_stations) - 1))
        for f, t in zip(node_names[c][:-1], node_names[c][1:]):
            G.add_edge(f, t, length = randint(5, 8), weight = 4, color = c / (len(n_stations) - 1))
    c = 0
    d = DSU(len(n_stations))
    while c != len(n_stations)-1:
        i, j = randint(0, len(n_stations) - 1), randint(0, len(n_stations) - 1)
        if d.get(i) != d.get(j):
            f, t = choice(node_names[i]), choice(node_names[j])
            G.add_edge(f, t, length = randint(2, 5), weight = 2, color = -1)
            d.join(i, j)
            c+=1

    return G

# %%
import io
def get_svg(g):
    G = gen_graph(g)
    print(G.edges())
    cmap = plt.cm.get_cmap('gist_rainbow')
    node_colors = [cmap(i[1]['color']) if i[1]['color'] != -1 else (0.2, 0.2, 0.2, 1.0) for i in G.nodes(data=True)]
    edge_colors = [cmap(i[2]['color']) if i[2]['color'] != -1 else (0.2, 0.2, 0.2, 1.0) for i in G.edges(data=True)]
    edge_labels = {(i[0], i[1]): i[2]['length'] for i in G.edges(data=True)}

    plt.figure(figsize=(50, 50)) 
    # pos = nx.kamada_kawai_layout(G)
    # print(pos)
    pos = nx.kamada_kawai_layout(G, weight='weight')
    print(pos)
    nx.draw_networkx_edge_labels(G, pos, edge_labels=edge_labels)
    nx.draw(G, pos, 
                  with_labels=True, 
                  node_size=300,
                  node_color=node_colors,
                  edge_color=edge_colors,
                  width=10.0)
    t = io.StringIO()
    plt.savefig(t, format='svg')
    t.seek(0)
    return t.read()

# %%
a = get_svg([4]*3)
a
# Out:
# [('Severn', 'Imperial'), ('Imperial', 'Lulu'), ('Lulu', 'Gerke'), ('Lulu', 'Shafter'), ('Oak Access', 'Peabody'), ('Oak Access', 'Diamond Heights'), ('Peabody', 'Shafter'), ('Shafter', 'Pollard'), ('Moraga', 'Thorp'), ('Thorp', 'Diamond Heights'), ('Diamond Heights', 'Saint Francis')]
# {'Severn': array([0.61479989, 0.79473963]), 'Imperial': array([0.35778983, 0.60022751]), 'Lulu': array([0.04607612, 0.4560252 ]), 'Gerke': array([-0.10984001,  0.76905453]), 'Oak Access': array([-0.01651446, -0.35198432]), 'Peabody': array([-0.01833492, -0.0219759 ]), 'Shafter': array([-0.04701367,  0.31913403]), 'Pollard': array([-0.3965303 ,  0.39571584]), 'Moraga': array([-0.4490517, -1.       ]), 'Thorp': array([-0.25571005, -0.74763776]), 'Diamond Heights': array([-0.00883841, -0.51310714]), 'Saint Francis': array([ 0.28316767, -0.70019162])}
# '<?xml version="1.0" encoding="utf-8" standalone="no"?>\n<!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"\n  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">\n<!-- Created with matplotlib (https://matplotlib.org/) -->\n<svg height="3600pt" version="1.1" viewBox="0 0 3600 3600" width="3600pt" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">\n <defs>\n  <style type="text/css">\n*{stroke-linecap:butt;stroke-linejoin:round;}\n  </style>\n </defs>\n <g id="figure_1">\n  <g id="patch_1">\n   <path d="M 0 3600 \nL 3600 3600 \nL 3600 0 \nL 0 0 \nz\n" style="fill:#ffffff;"/>\n  </g>\n  <g id="axes_1">\n   <g id="LineCollection_1">\n    <path clip-path="url(#p773815d670)" d="M 3105.824323 559.916619 \nL 2496.633094 826.763841 \n" style="fill:none;stroke:#ff0029;stroke-width:10;"/>\n    <path clip-path="url(#p773815d670)" d="M 2496.633094 826.763841 \nL 1757.777729 1024.592055 \n" style="fill:none;stroke:#ff0029;stroke-width:10;"/>\n    <path clip-path="url(#p773815d670)" d="M 1757.777729 1024.592055 \nL 1388.209538 595.153496 \n" style="fill:none;stroke:#ff0029;stroke-width:10;"/>\n    <path clip-path="url(#p773815d670)" d="M 1757.777729 1024.592055 \nL 1537.12689 1212.390266 \n" style="fill:none;stroke:#333333;stroke-width:10;"/>\n    <path clip-path="url(#p773815d670)" d="M 1609.419193 2133.083861 \nL 1605.104144 1680.352027 \n" style="fill:none;stroke:#00ff8c;stroke-width:10;"/>\n    <path clip-path="url(#p773815d670)" d="M 1609.419193 2133.083861 \nL 1627.613741 2354.124982 \n" style="fill:none;stroke:#333333;stroke-width:10;"/>\n    <path clip-path="url(#p773815d670)" d="M 1605.104144 1680.352027 \nL 1537.12689 1212.390266 \n" style="fill:none;stroke:#00ff8c;stroke-width:10;"/>\n    <path clip-path="url(#p773815d670)" d="M 1537.12689 1212.390266 \nL 708.667207 1107.329236 \n" style="fill:none;stroke:#00ff8c;stroke-width:10;"/>\n    <path clip-path="url(#p773815d670)" d="M 584.175677 3022.083381 \nL 1042.453618 2675.872765 \n" style="fill:none;stroke:#ff00bf;stroke-width:10;"/>\n    <path clip-path="url(#p773815d670)" d="M 1042.453618 2675.872765 \nL 1627.613741 2354.124982 \n" style="fill:none;stroke:#ff00bf;stroke-width:10;"/>\n    <path clip-path="url(#p773815d670)" d="M 1627.613741 2354.124982 \nL 2319.756084 2610.782365 \n" style="fill:none;stroke:#ff00bf;stroke-width:10;"/>\n   </g>\n   <g id="text_1">\n    <g id="patch_2">\n     <path clip-path="url(#p773815d670)" d="M 2803.32016 701.537613 \nL 2808.441217 697.761878 \nQ 2810.855861 695.981571 2809.075554 693.566927 \nL 2803.332209 685.777184 \nQ 2801.551902 683.36254 2799.137258 685.142847 \nL 2794.0162 688.918582 \nQ 2791.601556 690.698889 2793.381863 693.113533 \nL 2799.125208 700.903276 \nQ 2800.905515 703.31792 2803.32016 701.537613 \nz\n" style="fill:#ffffff;stroke:#ffffff;stroke-linejoin:miter;"/>\n    </g>\n    <g clip-path="url(#p773815d670)">\n     <!-- 6 -->\n     <defs>\n      <path d="M 33.015625 40.375 \nQ 26.375 40.375 22.484375 35.828125 \nQ 18.609375 31.296875 18.609375 23.390625 \nQ 18.609375 15.53125 22.484375 10.953125 \nQ 26.375 6.390625 33.015625 6.390625 \nQ 39.65625 6.390625 43.53125 10.953125 \nQ 47.40625 15.53125 47.40625 23.390625 \nQ 47.40625 31.296875 43.53125 35.828125 \nQ 39.65625 40.375 33.015625 40.375 \nz\nM 52.59375 71.296875 \nL 52.59375 62.3125 \nQ 48.875 64.0625 45.09375 64.984375 \nQ 41.3125 65.921875 37.59375 65.921875 \nQ 27.828125 65.921875 22.671875 59.328125 \nQ 17.53125 52.734375 16.796875 39.40625 \nQ 19.671875 43.65625 24.015625 45.921875 \nQ 28.375 48.1875 33.59375 48.1875 \nQ 44.578125 48.1875 50.953125 41.515625 \nQ 57.328125 34.859375 57.328125 23.390625 \nQ 57.328125 12.15625 50.6875 5.359375 \nQ 44.046875 -1.421875 33.015625 -1.421875 \nQ 20.359375 -1.421875 13.671875 8.265625 \nQ 6.984375 17.96875 6.984375 36.375 \nQ 6.984375 53.65625 15.1875 63.9375 \nQ 23.390625 74.21875 37.203125 74.21875 \nQ 40.921875 74.21875 44.703125 73.484375 \nQ 48.484375 72.75 52.59375 71.296875 \nz\n" id="DejaVuSan ...
